# %% [markdown]
# # House Price EDA and Model Training

# %%
import sys
import os
rootpath = os.path.dirname(os.path.dirname(__vsc_ipynb_file__))

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)

# %%
# Defining Data Path
path = "data/house-prices-advanced-regression-techniques/train.csv"
df = pd.read_csv(os.path.join(rootpath,path))

# %%
# Checking Initial Length
len(df)
# Out:
# 1460

# %%
# Will be removed after in the next commit

# Columns that had either low feature importance or majority of the values were na

# df.drop(columns=["Id","PoolQC","Fence","MiscFeature","Alley","MasVnrType","FireplaceQu"],inplace=True)

# # Unnecessary features - based on feature importance from catboost
# unnecessary_feats = ['MSZoning', 'Street', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'BsmtFinSF2', 'Heating', 'HeatingQC', 'Electrical', 'LowQualFinSF', 'BsmtHalfBath', 'KitchenAbvGr', 'KitchenQual', 'Functional', 'GarageType', 'GarageQual', 'GarageCond', 'PavedDrive', 'MiscVal', 'SaleType', 'SaleCondition']

# df.drop(columns=unnecessary_feats,inplace=True)

# df[df.columns[df.isna().sum() > 0]].isna().sum()

# %%
# Final Columns to use to train Catboost model
final_cols = ['MSSubClass', 'LotFrontage', 'LotArea', 'LotShape', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'ExterQual',
       'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', 'CentralAir', '1stFlrSF',
       '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
       'GarageFinish', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MoSold',
       'YrSold']

train_cols = final_cols.copy()
train_cols.append("SalePrice")

df = df[train_cols]

df.dropna(inplace=True,how="any")
df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea LotShape  OverallQual  OverallCond  \
# 0          60         65.0     8450      Reg            7            5
# 1          20         80.0     9600      Reg            6            8
# 2          60         68.0    11250      IR1            7            5
# 3          70         60.0     9550      IR1            7            5
# 4          60         84.0    14260      IR1            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea ExterQual  BsmtFinSF1  BsmtUnfSF  \
# 0       2003          2003       196.0        Gd         706        150
# 1       1976          1976         0.0        TA         978        284
# 2       2001          2002       162.0        Gd         486        434
# 3       1915          1970         0.0        TA         216        540
# 4       2000          2000       350.0        Gd         655        490
#
#    TotalBsmtSF CentralAir  1stFlrSF  2ndFlrSF  GrLivArea  BsmtFullBath  \
# 0          856          Y       856       854       1710             1
# 1         1262          Y      1262         0       1262             0
# 2          920          Y       920       866       1786             1
# 3          756          Y       961       756       1717             1
# 4         1145          Y      1145      1053       2198             1
#
#    FullBath  HalfBath  BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# 0         2         1             3             8           0       2003.0
# 1         2         0             3             6           1       1976.0
# 2         2         1             3             6           1       2001.0
# 3         1         0             3             7           1       1998.0
# 4         2         1             4             9           1       2000.0
#
#   GarageFinish  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0          RFn           2         548           0           61
# 1          RFn           2         460         298            0
# 2          RFn           2         608           0           42
# 3          Unf           3         642           0           35
# 4          RFn           3         836         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MoSold  YrSold  SalePrice
# 0              0          0            0         0       2    2008     208500
# 1              0          0            0         0       5    2007     181500
# 2              0          0            0         0       9    2008     223500
# 3            272          0            0         0       2    2006     140000
# 4              0          0            0         0      12    2008     250000

# %%
# Length after processing data
len(df)
# Out:
# 1121

# %%
# Generate test data by picking random values from columns
def generate_sample_houseprice_points(df,num_samples = 100):
    bootstrapped_samples = []

    for _ in range(num_samples):
        bootstrap_sample = {col: df[col].sample(n=1).values[0] for col in df.columns}

        bootstrapped_samples.append(bootstrap_sample)

    return pd.DataFrame(bootstrapped_samples)

# %%
# Get train and eval data

from catboost import CatBoostRegressor
# Initialize data

train_data = df.drop(columns="SalePrice")
train_labels = df["SalePrice"]

# %%
non_numeric_columns = df.select_dtypes(exclude=['number']).columns.tolist()

# %%
# Initialize CatBoostRegressor and train it
model = CatBoostRegressor(iterations=100,
                          learning_rate=1,
                          depth=16,
                          verbose = True,
                          cat_features = non_numeric_columns)

model.fit(train_data, train_labels)
# Out:
# 0:	learn: 44903.4193547	total: 158ms	remaining: 15.6s
# 1:	learn: 33287.6717132	total: 1.67s	remaining: 1m 21s
# 2:	learn: 24691.5437296	total: 2.86s	remaining: 1m 32s
# 3:	learn: 19782.1199954	total: 3.92s	remaining: 1m 34s
# 4:	learn: 16126.3881764	total: 4.88s	remaining: 1m 32s
# 5:	learn: 13459.0207176	total: 5.85s	remaining: 1m 31s
# 6:	learn: 11668.7880929	total: 6.89s	remaining: 1m 31s
# 7:	learn: 9886.3056548	total: 7.86s	remaining: 1m 30s
# 8:	learn: 8392.8186455	total: 8.83s	remaining: 1m 29s
# 9:	learn: 6961.5414271	total: 9.65s	remaining: 1m 26s
# 10:	learn: 5621.9163685	total: 10.4s	remaining: 1m 24s
# 11:	learn: 4502.0066381	total: 11.2s	remaining: 1m 21s
# 12:	learn: 3604.4603126	total: 11.9s	remaining: 1m 19s
# 13:	learn: 3052.8621748	total: 12.5s	remaining: 1m 16s
# 14:	learn: 2510.4611690	total: 13.3s	remaining: 1m 15s
# 15:	learn: 2192.8592207	total: 14s	remaining: 1m 13s
# 16:	learn: 1821.5382861	total: 14.6s	remaining: 1m 11s
# 17:	learn: 1573.7421641	total: 15.3s	remaining: 1m 9s
# 18:	learn: 1325.3255028	total: 16s	remaining: 1m 8s
# 19:	learn: 1043.9296576	total: 16.7s	remaining: 1m 6s
# 20:	learn: 884.7321003	total: 17.5s	remaining: 1m 5s
# 21:	learn: 775.3024312	total: 18.3s	remaining: 1m 4s
# 22:	learn: 610.4190124	total: 18.9s	remaining: 1m 3s
# 23:	learn: 504.0307575	total: 19.6s	remaining: 1m 1s
# 24:	learn: 455.5931251	total: 20.3s	remaining: 1m
# 25:	learn: 397.5376946	total: 21.1s	remaining: 59.9s
# 69:	learn: 1.3359958	total: 50.5s	remaining: 21.7s
# 70:	learn: 1.2021192	total: 51.2s	remaining: 20.9s
# 71:	learn: 1.0593559	total: 51.8s	remaining: 20.1s
# 72:	learn: 0.9612207	total: 52.6s	remaining: 19.4s
# 73:	learn: 0.8490878	total: 53.4s	remaining: 18.8s
# 74:	learn: 0.7495866	total: 54.2s	remaining: 18.1s
# 75:	learn: 0.6671154	total: 54.8s	remaining: 17.3s
# 76:	learn: 0.6126053	total: 55.4s	remaining: 16.6s
# 77:	learn: 0.5336678	total: 56s	remaining: 15.8s
# 78:	learn: 0.4613518	total: 56.7s	remaining: 15.1s
# 79:	learn: 0.4340017	total: 57.3s	remaining: 14.3s
# 80:	learn: 0.4031890	total: 58s	remaining: 13.6s
# 81:	learn: 0.3758959	total: 58.7s	remaining: 12.9s
# 82:	learn: 0.3713195	total: 59.3s	remaining: 12.1s
# 83:	learn: 0.3379036	total: 59.4s	remaining: 11.3s
# 84:	learn: 0.2979329	total: 60s	remaining: 10.6s
# 85:	learn: 0.2785919	total: 1m	remaining: 9.88s
# 86:	learn: 0.2523286	total: 1m 1s	remaining: 9.16s
# 87:	learn: 0.2339342	total: 1m 1s	remaining: 8.44s
# 88:	learn: 0.2103594	total: 1m 2s	remaining: 7.73s
# 89:	learn: 0.1834371	total: 1m 3s	remaining: 7.03s
# 90:	learn: 0.1683832	total: 1m 3s	remaining: 6.32s
# 91:	learn: 0.1532650	total: 1m 4s	remaining: 5.62s
# 92:	learn: 0.1394535	total: 1m 5s	remaining: 4.91s
# 93:	learn: 0.1175292	total: 1m 5s	remaining: 4.2s
# 94:	learn: 0.1103874	total: 1m 5s	remaining: 3.47s
# 95:	learn: 0.1010105	total: 1m 6s	remaining: 2.78s
# 96:	learn: 0.0930065	total: 1m 7s	remaining: 2.08s
# 97:	learn: 0.0883889	total: 1m 7s	remaining: 1.39s
# 98:	learn: 0.0770837	total: 1m 8s	remaining: 693ms
# 99:	learn: 0.0688603	total: 1m 9s	remaining: 0us

# %%
# Check feature with low importance

# print([colname for colname,val in list(zip(train_data.columns,model.feature_importances_)) if val < 0.01])

# %%
model_path = 'models/checkpoints//housing_price_model.cbm'

# %%
# Save checkpoint
model.save_model(os.path.join(rootpath,model_path))
print(f"Model saved to {model_path}")
# Out:
# Model saved to models/checkpoints//housing_price_model.cbm

# %%
# Load catboost model and check on eval data
eval_data = generate_sample_houseprice_points(df,10).drop(columns="SalePrice")
loaded_model = CatBoostRegressor()
loaded_model.load_model(os.path.join(rootpath,model_path))
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
# Check evaluation results
preds = loaded_model.predict(eval_data)
eval_data["Predicted"] = preds
eval_data
# Out:
#    MSSubClass  LotFrontage  LotArea LotShape  OverallQual  OverallCond  \
# 0         120         50.0     8160      IR1            7            5
# 1          30         93.0    11367      IR1            5            5
# 2          60        120.0    10793      Reg            4            6
# 3          60         66.0     9020      IR1            7            8
# 4          20         69.0     8190      Reg            6            7
# 5          60         70.0    10186      IR1            7            5
# 6         120         75.0     8197      IR1            5            5
# 7          60         60.0     7332      Reg            6            5
# 8          45         52.0     9187      Reg            6            5
# 9          20         53.0    16321      IR1            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea ExterQual  BsmtFinSF1  BsmtUnfSF  \
# 0       1990          1953         0.0        TA           0        276
# 1       1973          1950         0.0        TA           0        184
# 2       1954          1953       450.0        TA          48       1158
# 3       1930          1950         0.0        TA           0        742
# 4       2004          1950         0.0        Ex         777        328
# 5       1940          1950       183.0        Gd         523       1652
# 6       2004          1963         0.0        Gd         483        322
# 7       1970          2005         0.0        TA           0       1571
# 8       1954          1977         0.0        TA         194       1008
# 9       1941          1974        74.0        Gd        1196        876
#
#    TotalBsmtSF CentralAir  1stFlrSF  2ndFlrSF  GrLivArea  BsmtFullBath  \
# 0         1337          Y      1212         0       1682             1
# 1          616          Y       765      1093       1456             0
# 2          912          Y      1423       920       1456             0
# 3          874          Y      1316       252       1961             0
# 4          738          Y       864       866        936             0
# 5         1069          Y      1055         0       1500             0
# 6          547          Y      1593       252        924             0
# 7         1522          Y       649         0       1626             0
# 8         1165          Y       768         0        864             0
# 9          732          Y      1746         0       1214             0
#
#    FullBath  HalfBath  BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  \
# 0         2         1             4             5           0       1993.0
# 1         2         1             3             6           1       2005.0
# 2         2         1             3             8           1       2003.0
# 3         2         0             2             8           0       2002.0
# 4         1         0             3             7           1       1986.0
# 5         2         1             3             6           1       2003.0
# 6         2         0             4             7           1       1939.0
# 7         2         1             1             7           0       1940.0
# 8         1         0             3             9           1       1989.0
# 9         2         0             3             5           1       1953.0
#
#   GarageFinish  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0          RFn           2         288           0           32
# 1          Fin           3         308           0           50
# 2          RFn           2         528         218            0
# 3          RFn           2         264           0            0
# 4          Unf           2         719         239            0
# 5          Fin           2         810         120           24
# 6          Unf           2         500         100           36
# 7          Unf           1         673         120           16
# 8          Fin           1         473         147            0
# 9          Fin           2         660          96            0
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MoSold  YrSold  \
# 0              0          0          385         0       8    2007
# 1            116          0            0         0       6    2008
# 2              0          0            0         0       5    2009
# 3              0          0            0         0       8    2006
# 4              0          0            0         0       9    2010
# 5              0          0            0         0       1    2006
# 6              0          0            0         0       5    2007
# 7              0          0            0         0      10    2007
# 8              0          0            0         0       7    2006
# 9              0          0            0         0       7    2008
#
#        Predicted
# 0  176824.222113
# 1  189646.107116
# 2  156754.820637
# 3  190696.440263
# 4  152075.452432
# 5  171037.036810
# 6  153098.442548
# 7  171083.125586
# 8  156115.039474
# 9  235894.014109
